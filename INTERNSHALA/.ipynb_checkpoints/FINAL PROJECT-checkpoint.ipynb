# %% [markdown]
# # Analysis of Coffee Shop Menu

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from statsmodels.formula.api import ols
from statsmodels.stats.anova import anova_lm
from bioinfokit.analys import stat
import statsmodels.formula.api as smf

# %% [markdown]
# # Import and study the data

# %%
df=pd.read_csv('CoffeeShopMenu.csv')

# %%
df
# Out:
#                       Category                                      Beverage  \
# 0                       Coffee                                 Brewed Coffee
# 1                       Coffee                                 Brewed Coffee
# 2                       Coffee                                 Brewed Coffee
# 3                       Coffee                                 Brewed Coffee
# 4      Classic Espresso Drinks                                   Caffe Latte
# ..                         ...                                           ...
# 233  Frappuccino Blended Creme  Strawberries & Creme (Without Whipped Cream)
# 234  Frappuccino Blended Creme  Strawberries & Creme (Without Whipped Cream)
# 235  Frappuccino Blended Creme  Strawberries & Creme (Without Whipped Cream)
# 236  Frappuccino Blended Creme  Strawberries & Creme (Without Whipped Cream)
# 237  Frappuccino Blended Creme  Strawberries & Creme (Without Whipped Cream)
#
#        Size         Milk  Calories  TotalFat  TransFat  SaturatedFat  Sodium  \
# 0     Short         None         3       0.1       0.0           0.0       0
# 1      Tall         None         4       0.1       0.0           0.0       0
# 2    Grande         None         5       0.1       0.0           0.0       0
# 3     Venti         None         5       0.1       0.0           0.0       0
# 4     Short  Nonfat Milk        70       0.1       0.1           0.0       5
# ..      ...          ...       ...       ...       ...           ...     ...
# 233  Grande   Whole Milk       260       4.0       2.0           0.1      10
# 234  Grande      Soymilk       240       2.0       0.2           0.0       0
# 235   Venti  Nonfat Milk       310       0.2       0.1           0.0       5
# 236   Venti   Whole Milk       350       6.0       3.0           0.2      15
# 237   Venti      Soymilk       320       3.2       0.4           0.0       0
#
#      TotalCarb  Cholesterol  DietaryFibre  Sugars  Protein
# 0            5            0             0       0      0.3
# 1           10            0             0       0      0.5
# 2           10            0             0       0      1.0
# 3           10            0             0       0      1.0
# 4           75           10             0       9      6.0
# ..         ...          ...           ...     ...      ...
# 233        190           53             0      52      4.0
# 234        180           51             1      49      3.0
# 235        260           70             0      69      6.0
# 236        260           70             0      68      6.0
# 237        250           67             1      64      5.0
#
# [238 rows x 14 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 238 entries, 0 to 237
# Data columns (total 14 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Category      238 non-null    object
#  1   Beverage      238 non-null    object
#  2   Size          238 non-null    object
#  3   Milk          238 non-null    object
#  4   Calories      238 non-null    int64
#  5   TotalFat      238 non-null    float64
#  6   TransFat      238 non-null    float64
#  7   SaturatedFat  238 non-null    float64
#  8   Sodium        238 non-null    int64
#  9   TotalCarb     238 non-null    int64
#  10  Cholesterol   238 non-null    int64
#  11  DietaryFibre  238 non-null    int64
#  12  Sugars        238 non-null    int64
#  13  Protein       238 non-null    float64
# dtypes: float64(4), int64(6), object(4)
# memory usage: 26.2+ KB

# %% [markdown]
# #  Exploratory Data Analysis

# %%
df.describe().T
# Out:
#               count        mean         std  min    25%    50%     75%    max
# Calories      238.0  193.810924  103.668135  0.0  120.0  185.0  260.00  510.0
# TotalFat      238.0    2.931933    2.956133  0.0    0.2    2.5    4.50   15.0
# TransFat      238.0    1.318908    1.648097  0.0    0.1    0.5    2.00    9.0
# SaturatedFat  238.0    0.037815    0.071737  0.0    0.0    0.0    0.10    0.3
# Sodium        238.0    6.407563    8.679348  0.0    0.0    5.0   10.00   40.0
# TotalCarb     238.0  128.067227   82.656396  0.0   70.0  120.0  170.00  340.0
# Cholesterol   238.0   35.878151   20.927388  0.0   21.0   34.0   50.75   90.0
# DietaryFibre  238.0    0.815126    1.455189  0.0    0.0    0.0    1.00    8.0
# Sugars        238.0   32.819328   19.838082  0.0   18.0   32.0   43.75   84.0
# Protein       238.0    7.032773    4.893173  0.0    3.0    6.0   10.00   20.0

# %%
sns.kdeplot(df.Calories)
# Out:
# <Axes: xlabel='Calories', ylabel='Density'>

# %%
sns.distplot(df.Calories)
# Out:
# C:\Users\Sidd-pc\AppData\Local\Temp\ipykernel_6272\3701498214.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df.Calories)
# <Axes: xlabel='Calories', ylabel='Density'>

# %%
objnames=df.dtypes[df.dtypes=='object'].index
numnames=df.dtypes[df.dtypes!='object'].index

# %%
objnames
# Out:
# Index(['Category', 'Beverage', 'Size', 'Milk'], dtype='object')

# %%
numnames
# Out:
# Index(['Calories', 'TotalFat', 'TransFat', 'SaturatedFat', 'Sodium',
#        'TotalCarb', 'Cholesterol', 'DietaryFibre', 'Sugars', 'Protein'],
#       dtype='object')

# %%
len(numnames)
# Out:
# 10

# %%
plt.figure(figsize=(15,6))
count=1
for i in numnames:
    plt.subplot(2,5,count)
    sns.boxplot(df.loc[:,i], orient='h')
    count=count+1

# %%
plt.figure(figsize=(15,6))
count=1
for i in numnames:
    plt.subplot(2,5,count)
    sns.kdeplot(df.loc[:,i])
    count=count+1

# %%
objnames
# Out:
# Index(['Category', 'Beverage', 'Size', 'Milk'], dtype='object')

# %%
plt.figure(figsize=(8,8))
sns.boxplot(x=df.Calories,y=df.Beverage)
# Out:
# <Axes: xlabel='Calories', ylabel='Beverage'>

# %%
plt.figure(figsize=(8,8))
sns.boxplot(x=df.Calories,y=df.Category)
# Out:
# <Axes: xlabel='Calories', ylabel='Category'>

# %%
plt.figure(figsize=(8,8))
sns.boxplot(x=df.Calories,y=df.Milk)
# Out:
# <Axes: xlabel='Calories', ylabel='Milk'>

# %%
plt.figure(figsize=(8,8))
sns.boxplot(x=df.Calories,y=df.Size)
# Out:
# <Axes: xlabel='Calories', ylabel='Size'>

# %%
df.corr()
# Out:
# C:\Users\Sidd-pc\AppData\Local\Temp\ipykernel_6272\1134722465.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr()
#               Calories  TotalFat  TransFat  SaturatedFat    Sodium  TotalCarb  \
# Calories      1.000000  0.636476  0.645691      0.332305  0.388229   0.796933
# TotalFat      0.636476  1.000000  0.889677      0.618044  0.585912   0.460300
# TransFat      0.645691  0.889677  1.000000      0.693413  0.706656   0.533636
# SaturatedFat  0.332305  0.618044  0.693413      1.000000  0.920493   0.242933
# Sodium        0.388229  0.585912  0.706656      0.920493  1.000000   0.294795
# TotalCarb     0.796933  0.460300  0.533636      0.242933  0.294795   1.000000
# Cholesterol   0.940820  0.379539  0.445614      0.164689  0.201423   0.765836
# DietaryFibre  0.386000  0.257285  0.129895     -0.094424 -0.061158   0.178905
# Sugars        0.911007  0.338384  0.426742      0.182713  0.208555   0.770051
# Protein       0.581001  0.549996  0.496012      0.288548  0.496262   0.419695
#
#               Cholesterol  DietaryFibre    Sugars   Protein
# Calories         0.940820      0.386000  0.911007  0.581001
# TotalFat         0.379539      0.257285  0.338384  0.549996
# TransFat         0.445614      0.129895  0.426742  0.496012
# SaturatedFat     0.164689     -0.094424  0.182713  0.288548
# Sodium           0.201423     -0.061158  0.208555  0.496262
# TotalCarb        0.765836      0.178905  0.770051  0.419695
# Cholesterol      1.000000      0.346333  0.984227  0.365335
# DietaryFibre     0.346333      1.000000  0.188848  0.539622
# Sugars           0.984227      0.188848  1.000000  0.268728
# Protein          0.365335      0.539622  0.268728  1.000000

# %%
plt.figure(figsize=(8,8))
sns.heatmap(df.corr(),annot=True, cmap='rainbow')
# Out:
# C:\Users\Sidd-pc\AppData\Local\Temp\ipykernel_6272\3557677502.py:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df.corr(),annot=True, cmap='rainbow')
# <Axes: >

# %%
plt.figure(figsize=(10,10))
sns.pairplot(df)

# %%
df.Size.value_counts()
# Out:
# Grande    72
# Tall      63
# Venti     63
# Short     38
# Single     1
# Double     1
# Name: Size, dtype: int64

# %%
df.Milk.value_counts()
# Out:
# Nonfat Milk    81
# Soymilk        65
# 2% Milk        50
# None           27
# Whole Milk     15
# Name: Milk, dtype: int64

# %%
df.Category.value_counts()
# Out:
# Classic Espresso Drinks             58
# Tazo Tea Drinks                     52
# Signature Espresso Drinks           40
# Frappuccino Blended Coffee          36
# Shaken Iced Beverages               18
# Frappuccino Light Blended Coffee    12
# Smoothies                            9
# Frappuccino Blended Creme            9
# Coffee                               4
# Name: Category, dtype: int64

# %%
df.Beverage.value_counts()
# Out:
# Tazo Full-Leaf Red Tea Latte (Vanilla Rooibos)        12
# Caffe Latte                                           12
# Caffe Mocha (Without Whipped Cream)                   12
# Vanilla Latte (Or Other Flavoured Latte)              12
# Cappuccino                                            12
# Caramel Macchiato                                     12
# White Chocolate Mocha (Without Whipped Cream)         12
# Hot Chocolate (Without Whipped Cream)                 12
# Coffee                                                12
# Tazo Chai Tea Latte                                   12
# Tazo Green Tea Latte                                  12
# Tazo Full-Leaf Tea Latte                              12
# Java Chip (Without Whipped Cream)                      9
# Caramel (Without Whipped Cream)                        9
# Mocha (Without Whipped Cream)                          9
# Iced Brewed Coffee (With Milk & Classic Syrup)         9
# Strawberries & Creme (Without Whipped Cream)           9
# Tazo Tea                                               4
# Caramel Apple Spice (Without Whipped Cream)            4
# Skinny Latte (Any Flavour)                             4
# Caffe Americano                                        4
# Brewed Coffee                                          4
# Iced Brewed Coffee (With Classic Syrup)                3
# Shaken Iced Tazo Tea (With Classic Syrup)              3
# Shaken Iced Tazo Tea Lemonade (With Classic Syrup)     3
# Banana Chocolate Smoothie                              3
# Orange Mango Banana Smoothie                           3
# Strawberry Banana Smoothie                             3
# Mocha                                                  3
# Caramel                                                3
# Java Chip                                              3
# Espresso                                               2
# Name: Beverage, dtype: int64

# %%
df.groupby('Category').mean().sort_values('Calories',ascending=False)
# Out:
# C:\Users\Sidd-pc\AppData\Local\Temp\ipykernel_6272\2031106031.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby('Category').mean().sort_values('Calories',ascending=False)
#                                     Calories  TotalFat  TransFat  \
# Category
# Smoothies                         282.222222  2.333333  0.933333
# Frappuccino Blended Coffee        276.944444  3.002778  1.700000
# Signature Espresso Drinks         250.000000  5.275000  2.712500
# Frappuccino Blended Creme         248.888889  2.244444  0.844444
# Tazo Tea Drinks                   177.307692  2.540385  0.859615
# Frappuccino Light Blended Coffee  162.500000  1.258333  0.900000
# Classic Espresso Drinks           140.172414  3.127586  1.210345
# Shaken Iced Beverages             114.444444  0.472222  0.138889
# Coffee                              4.250000  0.100000  0.000000
#
#                                   SaturatedFat    Sodium   TotalCarb  \
# Category
# Smoothies                             0.011111  6.111111  132.777778
# Frappuccino Blended Coffee            0.038889  4.444444  230.277778
# Signature Espresso Drinks             0.050000  9.625000  138.250000
# Frappuccino Blended Creme             0.044444  4.444444  193.888889
# Tazo Tea Drinks                       0.044231  7.211538   89.903846
# Frappuccino Light Blended Coffee      0.000000  1.666667  217.500000
# Classic Espresso Drinks               0.046552  8.103448  104.672414
# Shaken Iced Beverages                 0.005556  1.111111   18.277778
# Coffee                                0.000000  0.000000    8.750000
#
#                                   Cholesterol  DietaryFibre     Sugars  \
# Category
# Smoothies                           54.555556      6.777778  36.777778
# Frappuccino Blended Coffee          59.638889      0.777778  57.083333
# Signature Espresso Drinks           42.775000      0.775000  38.600000
# Frappuccino Blended Creme           53.111111      0.333333  51.555556
# Tazo Tea Drinks                     31.692308      0.519231  30.307692
# Frappuccino Light Blended Coffee    34.500000      0.666667  32.416667
# Classic Espresso Drinks             20.327586      0.620690  16.965517
# Shaken Iced Beverages               26.166667      0.000000  26.000000
# Coffee                               0.000000      0.000000   0.000000
#
#                                     Protein
# Category
# Smoothies                         17.111111
# Frappuccino Blended Coffee         4.222222
# Signature Espresso Drinks          9.875000
# Frappuccino Blended Creme          4.111111
# Tazo Tea Drinks                    6.807692
# Frappuccino Light Blended Coffee   4.250000
# Classic Espresso Drinks            8.686207
# Shaken Iced Beverages              1.344444
# Coffee                             0.700000

# %%
df.groupby('Category').mean().sort_values('TotalFat',ascending=False)
# Out:
# C:\Users\Sidd-pc\AppData\Local\Temp\ipykernel_6272\2077192532.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby('Category').mean().sort_values('TotalFat',ascending=False)
#                                     Calories  TotalFat  TransFat  \
# Category
# Signature Espresso Drinks         250.000000  5.275000  2.712500
# Classic Espresso Drinks           140.172414  3.127586  1.210345
# Frappuccino Blended Coffee        276.944444  3.002778  1.700000
# Tazo Tea Drinks                   177.307692  2.540385  0.859615
# Smoothies                         282.222222  2.333333  0.933333
# Frappuccino Blended Creme         248.888889  2.244444  0.844444
# Frappuccino Light Blended Coffee  162.500000  1.258333  0.900000
# Shaken Iced Beverages             114.444444  0.472222  0.138889
# Coffee                              4.250000  0.100000  0.000000
#
#                                   SaturatedFat    Sodium   TotalCarb  \
# Category
# Signature Espresso Drinks             0.050000  9.625000  138.250000
# Classic Espresso Drinks               0.046552  8.103448  104.672414
# Frappuccino Blended Coffee            0.038889  4.444444  230.277778
# Tazo Tea Drinks                       0.044231  7.211538   89.903846
# Smoothies                             0.011111  6.111111  132.777778
# Frappuccino Blended Creme             0.044444  4.444444  193.888889
# Frappuccino Light Blended Coffee      0.000000  1.666667  217.500000
# Shaken Iced Beverages                 0.005556  1.111111   18.277778
# Coffee                                0.000000  0.000000    8.750000
#
#                                   Cholesterol  DietaryFibre     Sugars  \
# Category
# Signature Espresso Drinks           42.775000      0.775000  38.600000
# Classic Espresso Drinks             20.327586      0.620690  16.965517
# Frappuccino Blended Coffee          59.638889      0.777778  57.083333
# Tazo Tea Drinks                     31.692308      0.519231  30.307692
# Smoothies                           54.555556      6.777778  36.777778
# Frappuccino Blended Creme           53.111111      0.333333  51.555556
# Frappuccino Light Blended Coffee    34.500000      0.666667  32.416667
# Shaken Iced Beverages               26.166667      0.000000  26.000000
# Coffee                               0.000000      0.000000   0.000000
#
#                                     Protein
# Category
# Signature Espresso Drinks          9.875000
# Classic Espresso Drinks            8.686207
# Frappuccino Blended Coffee         4.222222
# Tazo Tea Drinks                    6.807692
# Smoothies                         17.111111
# Frappuccino Blended Creme          4.111111
# Frappuccino Light Blended Coffee   4.250000
# Shaken Iced Beverages              1.344444
# Coffee                             0.700000

# %%
df.groupby('Category').mean().sort_values('Protein',ascending=False)
# Out:
# C:\Users\Sidd-pc\AppData\Local\Temp\ipykernel_6272\2937330146.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby('Category').mean().sort_values('Protein',ascending=False)
#                                     Calories  TotalFat  TransFat  \
# Category
# Smoothies                         282.222222  2.333333  0.933333
# Signature Espresso Drinks         250.000000  5.275000  2.712500
# Classic Espresso Drinks           140.172414  3.127586  1.210345
# Tazo Tea Drinks                   177.307692  2.540385  0.859615
# Frappuccino Light Blended Coffee  162.500000  1.258333  0.900000
# Frappuccino Blended Coffee        276.944444  3.002778  1.700000
# Frappuccino Blended Creme         248.888889  2.244444  0.844444
# Shaken Iced Beverages             114.444444  0.472222  0.138889
# Coffee                              4.250000  0.100000  0.000000
#
#                                   SaturatedFat    Sodium   TotalCarb  \
# Category
# Smoothies                             0.011111  6.111111  132.777778
# Signature Espresso Drinks             0.050000  9.625000  138.250000
# Classic Espresso Drinks               0.046552  8.103448  104.672414
# Tazo Tea Drinks                       0.044231  7.211538   89.903846
# Frappuccino Light Blended Coffee      0.000000  1.666667  217.500000
# Frappuccino Blended Coffee            0.038889  4.444444  230.277778
# Frappuccino Blended Creme             0.044444  4.444444  193.888889
# Shaken Iced Beverages                 0.005556  1.111111   18.277778
# Coffee                                0.000000  0.000000    8.750000
#
#                                   Cholesterol  DietaryFibre     Sugars  \
# Category
# Smoothies                           54.555556      6.777778  36.777778
# Signature Espresso Drinks           42.775000      0.775000  38.600000
# Classic Espresso Drinks             20.327586      0.620690  16.965517
# Tazo Tea Drinks                     31.692308      0.519231  30.307692
# Frappuccino Light Blended Coffee    34.500000      0.666667  32.416667
# Frappuccino Blended Coffee          59.638889      0.777778  57.083333
# Frappuccino Blended Creme           53.111111      0.333333  51.555556
# Shaken Iced Beverages               26.166667      0.000000  26.000000
# Coffee                               0.000000      0.000000   0.000000
#
#                                     Protein
# Category
# Smoothies                         17.111111
# Signature Espresso Drinks          9.875000
# Classic Espresso Drinks            8.686207
# Tazo Tea Drinks                    6.807692
# Frappuccino Light Blended Coffee   4.250000
# Frappuccino Blended Coffee         4.222222
# Frappuccino Blended Creme          4.111111
# Shaken Iced Beverages              1.344444
# Coffee                             0.700000

# %%
pd.pivot_table(data=df, values='Calories', index='Category', columns='Milk', aggfunc='mean')
# Out:
# Milk                                 2% Milk        None  Nonfat Milk  \
# Category
# Classic Espresso Drinks           184.375000   11.666667   134.500000
# Coffee                                   NaN    4.250000          NaN
# Frappuccino Blended Coffee               NaN         NaN   267.500000
# Frappuccino Blended Creme                NaN         NaN   236.666667
# Frappuccino Light Blended Coffee         NaN         NaN   162.500000
# Shaken Iced Beverages             130.000000  106.666667   116.666667
# Signature Espresso Drinks         275.833333  247.500000   233.333333
# Smoothies                         286.666667         NaN   276.666667
# Tazo Tea Drinks                   211.875000    0.000000   175.625000
#
# Milk                                 Soymilk  Whole Milk
# Category
# Classic Espresso Drinks           151.250000         NaN
# Coffee                                   NaN         NaN
# Frappuccino Blended Coffee        268.333333  295.000000
# Frappuccino Blended Creme         243.333333  266.666667
# Frappuccino Light Blended Coffee         NaN         NaN
# Shaken Iced Beverages             120.000000         NaN
# Signature Espresso Drinks         241.666667         NaN
# Smoothies                         283.333333         NaN
# Tazo Tea Drinks                   188.750000         NaN

# %%
df[df.Category=='Coffee']
# Out:
#   Category       Beverage    Size  Milk  Calories  TotalFat  TransFat  \
# 0   Coffee  Brewed Coffee   Short  None         3       0.1       0.0
# 1   Coffee  Brewed Coffee    Tall  None         4       0.1       0.0
# 2   Coffee  Brewed Coffee  Grande  None         5       0.1       0.0
# 3   Coffee  Brewed Coffee   Venti  None         5       0.1       0.0
#
#    SaturatedFat  Sodium  TotalCarb  Cholesterol  DietaryFibre  Sugars  Protein
# 0           0.0       0          5            0             0       0      0.3
# 1           0.0       0         10            0             0       0      0.5
# 2           0.0       0         10            0             0       0      1.0
# 3           0.0       0         10            0             0       0      1.0

# %% [markdown]
# # ANOVA

# %%
sns.boxplot(x=df.Calories, y=df.Milk)
# Out:
# <Axes: xlabel='Calories', ylabel='Milk'>

# %%
formula='Calories~C(Milk)'
model=ols(formula,df).fit()
aov_table=anova_lm(model)
print(aov_table)
# Out:
#              df        sum_sq        mean_sq          F        PR(>F)
# C(Milk)     4.0  5.584364e+05  139609.099632  16.357517  7.975236e-12
# Residual  233.0  1.988622e+06    8534.858769        NaN           NaN

# %%
dfnew=df[df.Milk!='None']
dfnew.shape,df.shape
# Out:
# ((211, 14), (238, 14))

# %%
sns.boxplot(x=dfnew.Calories, y= dfnew.Milk)
# Out:
# <Axes: xlabel='Calories', ylabel='Milk'>

# %%
formula='Calories~C(Milk)'
model=ols(formula,dfnew).fit()
aov_table=anova_lm(model)
print(aov_table)
# Out:
#              df        sum_sq       mean_sq         F    PR(>F)
# C(Milk)     3.0  1.317432e+05  43914.396571  5.184292  0.001789
# Residual  207.0  1.753427e+06   8470.663896       NaN       NaN

# %%
res=stat()
res.tukey_hsd(dfnew,
             res_var='Calories',
             xfac_var='Milk',
             anova_model='Calories~C(Milk)')
res.tukey_summary
# Out:
# C:\Users\Sidd-pc\anaconda3\Lib\site-packages\bioinfokit\analys.py:421: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   mult_group[ele] = df[df[xfac_var] == ele].mean().loc[res_var]
# C:\Users\Sidd-pc\anaconda3\Lib\site-packages\bioinfokit\analys.py:421: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   mult_group[ele] = df[df[xfac_var] == ele].mean().loc[res_var]
# C:\Users\Sidd-pc\anaconda3\Lib\site-packages\bioinfokit\analys.py:421: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   mult_group[ele] = df[df[xfac_var] == ele].mean().loc[res_var]
# C:\Users\Sidd-pc\anaconda3\Lib\site-packages\bioinfokit\analys.py:421: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   mult_group[ele] = df[df[xfac_var] == ele].mean().loc[res_var]
#         group1      group2       Diff      Lower       Upper   q-value  \
# 0  Nonfat Milk     2% Milk  28.493827 -14.380041   71.367696  2.434439
# 1  Nonfat Milk     Soymilk  18.186135 -21.511239   57.883509  1.678106
# 2  Nonfat Milk  Whole Milk  99.827160  32.818334  166.835987  5.457045
# 3      2% Milk     Soymilk  10.307692 -34.535010   55.150395  0.841997
# 4      2% Milk  Whole Milk  71.333333   1.153783  141.512884  3.723255
# 5      Soymilk  Whole Milk  81.641026  13.355726  149.926326  4.379475
#
#     p-value
# 0  0.315317
# 1  0.620007
# 2  0.001000
# 3  0.900000
# 4  0.044752
# 5  0.011860

# %%
sns.boxplot(x=dfnew.Calories, y= dfnew.Milk)
# Out:
# <Axes: xlabel='Calories', ylabel='Milk'>

# %% [markdown]
# # Linear Regression

# %%
df.columns
# Out:
# Index(['Category', 'Beverage', 'Size', 'Milk', 'Calories', 'TotalFat',
#        'TransFat', 'SaturatedFat', 'Sodium', 'TotalCarb', 'Cholesterol',
#        'DietaryFibre', 'Sugars', 'Protein'],
#       dtype='object')

# %%
formula='Calories~Category+Beverage+Size+Milk+TotalFat+TransFat+SaturatedFat+Sodium+TotalCarb+Cholesterol+DietaryFibre+Sugars+Protein'
lm=smf.ols(formula,data=df).fit()
print(lm.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:               Calories   R-squared:                       0.999
# Model:                            OLS   Adj. R-squared:                  0.998
# Method:                 Least Squares   F-statistic:                     2673.
# Date:                Fri, 13 Oct 2023   Prob (F-statistic):          3.27e-244
# Time:                        20:10:58   Log-Likelihood:                -665.69
# No. Observations:                 238   AIC:                             1429.
# Df Residuals:                     189   BIC:                             1600.
# Df Model:                          48
# Covariance Type:            nonrobust
# ==================================================================================================================================
#                                                                      coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------------------------------------------
# Intercept                                                          5.9159      2.427      2.438      0.016       1.129      10.703
# Category[T.Coffee]                                                -1.7858      1.328     -1.345      0.180      -4.405       0.833
# Category[T.Frappuccino Blended Coffee]                            -6.2365      2.749     -2.269      0.024     -11.660      -0.814
# Category[T.Frappuccino Blended Creme]                             -2.4348      1.535     -1.587      0.114      -5.462       0.592
# Category[T.Frappuccino Light Blended Coffee]                      -7.1418      2.837     -2.518      0.013     -12.737      -1.546
# Category[T.Shaken Iced Beverages]                                 -3.8096      1.881     -2.025      0.044      -7.521      -0.098
# Category[T.Signature Espresso Drinks]                              1.4891      1.665      0.895      0.372      -1.794       4.773
# Category[T.Smoothies]                                             11.5911      7.981      1.452      0.148      -4.152      27.335
# Category[T.Tazo Tea Drinks]                                        0.6722      1.297      0.518      0.605      -1.887       3.231
# Beverage[T.Brewed Coffee]                                         -1.7858      1.328     -1.345      0.180      -4.405       0.833
# Beverage[T.Caffe Americano]                                        1.5733      2.253      0.698      0.486      -2.870       6.017
# Beverage[T.Caffe Latte]                                            6.5697      2.039      3.222      0.002       2.547      10.593
# Beverage[T.Caffe Mocha (Without Whipped Cream)]                   -7.2393      2.244     -3.225      0.001     -11.667      -2.812
# Beverage[T.Cappuccino]                                             1.3637      1.750      0.779      0.437      -2.088       4.815
# Beverage[T.Caramel]                                                0.9622      3.079      0.312      0.755      -5.112       7.036
# Beverage[T.Caramel (Without Whipped Cream)]                        0.7891      2.379      0.332      0.740      -3.904       5.482
# Beverage[T.Caramel Apple Spice (Without Whipped Cream)]            5.9540      3.447      1.727      0.086      -0.845      12.753
# Beverage[T.Caramel Macchiato]                                      4.2360      1.708      2.479      0.014       0.866       7.606
# Beverage[T.Coffee]                                                 0.3118      1.961      0.159      0.874      -3.556       4.180
# Beverage[T.Espresso]                                               0.0861      3.288      0.026      0.979      -6.400       6.573
# Beverage[T.Hot Chocolate (Without Whipped Cream)]                -12.1538      1.750     -6.946      0.000     -15.605      -8.702
# Beverage[T.Iced Brewed Coffee (With Classic Syrup)]                1.6434      2.211      0.743      0.458      -2.719       6.006
# Beverage[T.Iced Brewed Coffee (With Milk & Classic Syrup)]         0.0128      1.774      0.007      0.994      -3.486       3.512
# Beverage[T.Java Chip]                                             -4.0320      3.376     -1.194      0.234     -10.692       2.628
# Beverage[T.Java Chip (Without Whipped Cream)]                     -4.8860      2.873     -1.701      0.091     -10.554       0.782
# Beverage[T.Mocha]                                                 -1.4804      2.898     -0.511      0.610      -7.196       4.235
# Beverage[T.Mocha (Without Whipped Cream)]                         -5.0429      2.118     -2.381      0.018      -9.221      -0.865
# Beverage[T.Orange Mango Banana Smoothie]                           4.7607      3.961      1.202      0.231      -3.053      12.574
# Beverage[T.Shaken Iced Tazo Tea (With Classic Syrup)]             -3.2652      2.208     -1.479      0.141      -7.620       1.090
# Beverage[T.Shaken Iced Tazo Tea Lemonade (With Classic Syrup)]    -2.2006      2.421     -0.909      0.365      -6.977       2.576
# Beverage[T.Skinny Latte (Any Flavour)]                             4.8707      2.649      1.839      0.068      -0.355      10.096
# Beverage[T.Strawberries & Creme (Without Whipped Cream)]          -2.4348      1.535     -1.587      0.114      -5.462       0.592
# Beverage[T.Strawberry Banana Smoothie]                             6.7146      4.001      1.678      0.095      -1.178      14.607
# Beverage[T.Tazo Chai Tea Latte]                                   -0.8742      1.661     -0.526      0.599      -4.150       2.402
# Beverage[T.Tazo Full-Leaf Red Tea Latte (Vanilla Rooibos)]        -0.2010      1.334     -0.151      0.880      -2.833       2.431
# Beverage[T.Tazo Full-Leaf Tea Latte]                              -0.2010      1.334     -0.151      0.880      -2.833       2.431
# Beverage[T.Tazo Green Tea Latte]                                   6.9737      2.137      3.263      0.001       2.758      11.189
# Beverage[T.Tazo Tea]                                              -5.0254      2.391     -2.101      0.037      -9.743      -0.308
# Beverage[T.Vanilla Latte (Or Other Flavoured Latte)]               6.3477      1.922      3.303      0.001       2.557      10.139
# Beverage[T.White Chocolate Mocha (Without Whipped Cream)]          3.4529      2.728      1.266      0.207      -1.927       8.833
# Size[T.Grande]                                                     2.9865      1.207      2.475      0.014       0.606       5.367
# Size[T.Short]                                                     -2.2544      1.161     -1.941      0.054      -4.545       0.037
# Size[T.Single]                                                    -1.1644      6.316     -0.184      0.854     -13.624      11.295
# Size[T.Tall]                                                       0.8889      0.887      1.002      0.318      -0.861       2.639
# Size[T.Venti]                                                      4.2089      1.947      2.161      0.032       0.367       8.050
# Milk[T.None]                                                      -3.0201      2.213     -1.365      0.174      -7.386       1.346
# Milk[T.Nonfat Milk]                                               -0.7602      1.915     -0.397      0.692      -4.539       3.018
# Milk[T.Soymilk]                                                   -0.6926      1.903     -0.364      0.716      -4.447       3.062
# Milk[T.Whole Milk]                                                 0.8221      1.795      0.458      0.647      -2.718       4.363
# TotalFat                                                          10.2621      0.631     16.264      0.000       9.017      11.507
# TransFat                                                          -1.6747      1.339     -1.250      0.213      -4.317       0.967
# SaturatedFat                                                     -13.2391     18.450     -0.718      0.474     -49.634      23.156
# Sodium                                                            -0.1745      0.185     -0.942      0.347      -0.540       0.191
# TotalCarb                                                          0.0298      0.022      1.346      0.180      -0.014       0.073
# Cholesterol                                                        1.9358      0.486      3.981      0.000       0.977       2.895
# DietaryFibre                                                       0.0529      1.192      0.044      0.965      -2.298       2.404
# Sugars                                                             2.0113      0.488      4.121      0.000       1.049       2.974
# Protein                                                            3.1168      0.331      9.420      0.000       2.464       3.769
# ==============================================================================
# Omnibus:                       39.833   Durbin-Watson:                   2.032
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              122.960
# Skew:                           0.678   Prob(JB):                     1.99e-27
# Kurtosis:                       6.250   Cond. No.                     2.52e+16
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 9.82e-27. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.

# %%
formula='Calories~TotalFat+Sugars+Protein'
lm=smf.ols(formula=formula, data=df).fit()
print(lm.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:               Calories   R-squared:                       0.992
# Model:                            OLS   Adj. R-squared:                  0.991
# Method:                 Least Squares   F-statistic:                     9152.
# Date:                Fri, 13 Oct 2023   Prob (F-statistic):          3.42e-242
# Time:                        20:13:25   Log-Likelihood:                -873.77
# No. Observations:                 238   AIC:                             1756.
# Df Residuals:                     234   BIC:                             1769.
# Df Model:                           3
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      1.7872      1.365      1.309      0.192      -0.902       4.476
# TotalFat       8.6220      0.260     33.195      0.000       8.110       9.134
# Sugars         3.9879      0.034    118.833      0.000       3.922       4.054
# Protein        5.0997      0.153     33.266      0.000       4.798       5.402
# ==============================================================================
# Omnibus:                       41.852   Durbin-Watson:                   1.548
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               67.363
# Skew:                           0.982   Prob(JB):                     2.36e-15
# Kurtosis:                       4.713   Cond. No.                         85.8
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
formula='Calories~TransFat+Sugars+Protein'
lm=smf.ols(formula=formula, data=df).fit()
print(lm.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:               Calories   R-squared:                       0.973
# Model:                            OLS   Adj. R-squared:                  0.973
# Method:                 Least Squares   F-statistic:                     2820.
# Date:                Fri, 13 Oct 2023   Prob (F-statistic):          2.50e-183
# Time:                        20:13:57   Log-Likelihood:                -1011.6
# No. Observations:                 238   AIC:                             2031.
# Df Residuals:                     234   BIC:                             2045.
# Df Model:                           3
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      6.1205      2.472      2.476      0.014       1.250      10.991
# TransFat      11.2974      0.830     13.616      0.000       9.663      12.932
# Sugars         3.9549      0.062     63.647      0.000       3.833       4.077
# Protein        6.1130      0.262     23.298      0.000       5.596       6.630
# ==============================================================================
# Omnibus:                       20.110   Durbin-Watson:                   2.494
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               22.622
# Skew:                           0.709   Prob(JB):                     1.22e-05
# Kurtosis:                       3.520   Cond. No.                         87.1
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
pred=lm.predict(df)

# %%
sns.scatterplot(x=df.Calories,y=pred)
# Out:
# <Axes: xlabel='Calories'>

# %%
sns.scatterplot(x=df.Calories,y=pred-df.Calories)
# Out:
# <Axes: xlabel='Calories'>

# %%
sns.kdeplot(pred-df.Calories)
# Out:
# <Axes: ylabel='Density'>
